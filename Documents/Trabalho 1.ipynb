# %% [markdown]
# # Universidade Tecnológica Federal do Paraná
#
# # Disciplina de Tópicos em Programação 1
#
# # Alunos: Gabriel Vitor Siqueira
#
# # Professora: Simone de Almeida
#
# # Projeto de análise ao engajamento do Instagram

# %%
#importando a base pandas 
import pandas as pd
import matplotlib.pyplot as plt

# %%
#importando a base de dados
base = pd.read_excel("C:/Users/Gabriel Siqueira/Documents/engajamento instagram.xlsx")

# %%
#printando para ver se a base foi selecionada corretamente
base
# Out:
#      Tipo       Data  Curtidas  Comentários  Visualizações  \
# 0    Foto 2021-09-11      2858           16            NaN
# 1    Foto 2021-09-11      2930           28            NaN
# 2    Foto 2021-09-11      2807            9            NaN
# 3   Vídeo 2021-09-12      5115           49        82878.0
# 4    Foto 2021-09-13      4392           45            NaN
# 5    Foto 2021-09-17      5359           62            NaN
# 6    Foto 2021-09-19     21597          852            NaN
# 7    Foto 2021-09-25      6346           33            NaN
# 8    Foto 2021-09-27      6355           89            NaN
# 9   Vídeo 2021-09-28      4056           81        73174.0
# 10  Reels 2021-10-10     12894          249        92120.0
# 11   Foto 2021-10-12     17831          391            NaN
# 12   Foto 2021-10-21      6166           55            NaN
# 13   Foto 2021-10-24     15940          612            NaN
# 14   Foto 2021-10-29     14121          184            NaN
# ...

# %%
#comando base.drop ira excluir a coluna selecionada entre os colchetes, o axis se refere a 1 como elemento de coluna e o inplace
#motrando que o comando é verdadeiro para tal operação.
base.drop(["Visualizações"], axis= 1, inplace = True)
base.head()
# Out:
#     Tipo       Data  Curtidas  Comentários           Tags Pessoas Campanhas  \
# 0   Foto 2021-09-11      2858           16           Loja       N         N
# 1   Foto 2021-09-11      2930           28  Loja/Produtos       N         N
# 2   Foto 2021-09-11      2807            9           Loja       N         N
# 3  Vídeo 2021-09-12      5115           49       Produtos       N         N
# 4   Foto 2021-09-13      4392           45       Produtos       S         N
#
#   Carrossel  Interacoes
# 0       NaN         2874
# 1       NaN         2958
# 2       NaN         2816
# 3       NaN         5164
# 4       NaN         4437

# %%
# Mostrando as 5 primeiras linhas
base.head()
# Out:
#     Tipo       Data  Curtidas  Comentários           Tags Pessoas Campanhas  \
# 0   Foto 2021-09-11      2858           16           Loja       N         N
# 1   Foto 2021-09-11      2930           28  Loja/Produtos       N         N
# 2   Foto 2021-09-11      2807            9           Loja       N         N
# 3  Vídeo 2021-09-12      5115           49       Produtos       N         N
# 4   Foto 2021-09-13      4392           45       Produtos       S         N
#
#   Carrossel  Interacoes
# 0       NaN         2874
# 1       NaN         2958
# 2       NaN         2816
# 3       NaN         5164
# 4       NaN         4437

# %%
#Mostrando as 5 últimas linhas
base.tail()
# Out:
#     Tipo       Data  Curtidas  Comentários                               Tags  \
# 47  IGTV 2022-03-12      5489           77  Dicas de como usar/Novos Produtos
# 48  Foto 2022-03-20     29084          479      Datas comemorativas/Promoções
# 49  Foto 2022-03-22      9087          106                                NaN
# 50  Foto 2022-03-26     16551          186                                NaN
# 51  IGTV 2022-03-27      4934           65        Dicas de como usar/Produtos
#
#    Pessoas Campanhas Carrossel  Interacoes
# 47       S         N       NaN         5566
# 48       S         S       NaN        29563
# 49       S         S       NaN         9193
# 50       S         N       NaN        16737
# 51       S         N       NaN         4999

# %%
#tamanho da base (linhas e colunas)
base.shape
# Out:
# (52, 9)

# %%
# Visualizando primeiras e últimas linhas e tamanho da base
display(base)
# Out:
#      Tipo       Data  Curtidas  Comentários  \
# 0    Foto 2021-09-11      2858           16
# 1    Foto 2021-09-11      2930           28
# 2    Foto 2021-09-11      2807            9
# 3   Vídeo 2021-09-12      5115           49
# 4    Foto 2021-09-13      4392           45
# 5    Foto 2021-09-17      5359           62
# 6    Foto 2021-09-19     21597          852
# 7    Foto 2021-09-25      6346           33
# 8    Foto 2021-09-27      6355           89
# 9   Vídeo 2021-09-28      4056           81
# 10  Reels 2021-10-10     12894          249
# 11   Foto 2021-10-12     17831          391
# 12   Foto 2021-10-21      6166           55
# 13   Foto 2021-10-24     15940          612
# 14   Foto 2021-10-29     14121          184
# 15  Vídeo 2021-11-04      3646           71
# 16  Reels 2021-11-06      6376          137
# 17  Vídeo 2021-11-09      3213           60
# 18  Reels 2021-11-12      5493           59
# 19   Foto 2021-12-12     16086          268
# ...

# %%
#verificando os tipos de dados que a tabela mostra
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Tipo         52 non-null     object
#  1   Data         52 non-null     datetime64[ns]
#  2   Curtidas     52 non-null     int64
#  3   Comentários  52 non-null     int64
#  4   Tags         44 non-null     object
#  5   Pessoas      52 non-null     object
#  6   Campanhas    52 non-null     object
#  7   Carrossel    8 non-null      object
#  8   Interacoes   52 non-null     int64
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 3.8+ KB

# %%
#Cada coluna do DataFrame é tratada como uma séries, por isso aqui chamamos a base e atribuímos a ela o objeto que estamos 
# procurando e chamando a variável para ver os valores da tabela. Contando os valores que aparecem na tabela
series=base["Carrossel"].shape
series
# Out:
# (52,)

# %%
#buscando os valores que são nulos dentro da coluna Carrossel
is_null = pd.isna(base["Carrossel"])
base[is_null.values]
# Out:
#      Tipo       Data  Curtidas  Comentários  \
# 0    Foto 2021-09-11      2858           16
# 1    Foto 2021-09-11      2930           28
# 2    Foto 2021-09-11      2807            9
# 3   Vídeo 2021-09-12      5115           49
# 4    Foto 2021-09-13      4392           45
# 6    Foto 2021-09-19     21597          852
# 7    Foto 2021-09-25      6346           33
# 9   Vídeo 2021-09-28      4056           81
# 10  Reels 2021-10-10     12894          249
# 11   Foto 2021-10-12     17831          391
# 13   Foto 2021-10-24     15940          612
# 14   Foto 2021-10-29     14121          184
# 15  Vídeo 2021-11-04      3646           71
# 16  Reels 2021-11-06      6376          137
# 17  Vídeo 2021-11-09      3213           60
# 18  Reels 2021-11-12      5493           59
# 19   Foto 2021-12-12     16086          268
# 20   Foto 2021-12-16      2881           29
# 22   Foto 2021-12-26     18097          225
# 23   Foto 2021-12-28      8191           94
# ...

# %%
#buscando os valores que não são nulos dentro da coluna Carrossel
not_null = pd.notna(base["Carrossel"])
base[not_null.values]
# Out:
#     Tipo       Data  Curtidas  Comentários                 Tags Pessoas  \
# 5   Foto 2021-09-17      5359           62       Novos Produtos       N
# 8   Foto 2021-09-27      6355           89             Produtos       S
# 12  Foto 2021-10-21      6166           55       Novos Produtos       S
# 21  Foto 2021-12-23      8328           93             Produtos       S
# 25  Foto 2022-01-02     12193          138       Novos Produtos       S
# 26  Foto 2022-01-08     24585          354  Datas comemorativas       S
# 28  Foto 2022-01-15      9936          119       Novos Produtos       S
# 40  Foto 2022-02-21     21621          213      Influenciadores       S
#
#    Campanhas Carrossel  Interacoes
# 5          S         S         5421
# 8          N         S         6444
# 12         S         S         6221
# 21         N         S         8421
# 25         N         S        12331
# 26         S         S        24939
# 28         N         S        10055
# ...

# %%
#selecionando somente os valores de carrossel
base["Carrossel"]
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5       S
# 6     NaN
# 7     NaN
# 8       S
# 9     NaN
# 10    NaN
# 11    NaN
# 12      S
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21      S
# 22    NaN
# 23    NaN
# 24    NaN
# 25      S
# 26      S
# 27    NaN
# 28      S
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37    NaN
# 38    NaN
# 39    NaN
# 40      S
# 41    NaN
# 42    NaN
# 43    NaN
# 44    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 49    NaN
# 50    NaN
# 51    NaN
# Name: Carrossel, dtype: object

# %%
#Atribuindo o valor N para esse dataFrame
base["Carrossel"] = base["Carrossel"].apply(lambda x: "N" if pd.isna(x) else "S")
base
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 #Atribuindo o valor N para esse dataFrame
# ----> 2 base["Carrossel"] = base["Carrossel"].apply(lambda x: "N" if pd.isna(x) else "S")
#       3 base
#
# NameError: name 'base' is not defined

# %%
display(base)
# Out:
#      Tipo       Data  Curtidas  Comentários  \
# 0    Foto 2021-09-11      2858           16
# 1    Foto 2021-09-11      2930           28
# 2    Foto 2021-09-11      2807            9
# 3   Vídeo 2021-09-12      5115           49
# 4    Foto 2021-09-13      4392           45
# 5    Foto 2021-09-17      5359           62
# 6    Foto 2021-09-19     21597          852
# 7    Foto 2021-09-25      6346           33
# 8    Foto 2021-09-27      6355           89
# 9   Vídeo 2021-09-28      4056           81
# 10  Reels 2021-10-10     12894          249
# 11   Foto 2021-10-12     17831          391
# 12   Foto 2021-10-21      6166           55
# 13   Foto 2021-10-24     15940          612
# 14   Foto 2021-10-29     14121          184
# 15  Vídeo 2021-11-04      3646           71
# 16  Reels 2021-11-06      6376          137
# 17  Vídeo 2021-11-09      3213           60
# 18  Reels 2021-11-12      5493           59
# 19   Foto 2021-12-12     16086          268
# ...

# %%
 base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Tipo         52 non-null     object
#  1   Data         52 non-null     datetime64[ns]
#  2   Curtidas     52 non-null     int64
#  3   Comentários  52 non-null     int64
#  4   Tags         44 non-null     object
#  5   Pessoas      52 non-null     object
#  6   Campanhas    52 non-null     object
#  7   Carrossel    52 non-null     object
#  8   Interacoes   52 non-null     int64
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 3.8+ KB

# %%
#Gráfico de dispersão ajudaria a entender melhor as curtidas e comentários
base.plot(kind="scatter",x="Data",y="Curtidas",figsize=(14,8));

# %%
# colocamos curtidas e comentários no mesmo gráfico

ax = base.plot(kind="scatter",x="Data",y="Curtidas",color="blue",label="Curtidas",figsize=(14,8));
base.plot(kind="scatter",x="Data",y="Comentários",color="red",label="Comentários",figsize=(14,8),ax=ax);

# %%
# A escala de curtidas pode estar atrapalhando a visualização, por isso vamos deixar comentários em um gráfico separado
base.plot(kind="scatter",x="Data",y="Comentários",color="red",label="Comentários",figsize=(14,8));

# %%
# Ordenando os valores
base.sort_values(by="Curtidas",ascending=False).head()
# Out:
#      Tipo       Data  Curtidas  Comentários                           Tags  \
# 39   Foto 2022-02-17     37351          502                      Promoções
# 30  Reels 2022-01-24     29981          502                         Trends
# 48   Foto 2022-03-20     29084          479  Datas comemorativas/Promoções
# 33   Foto 2022-02-06     24655          186                Influenciadores
# 26   Foto 2022-01-08     24585          354            Datas comemorativas
#
#    Pessoas Campanhas Carrossel  Interacoes
# 39       S         S         N        37853
# 30       S         S         N        30483
# 48       S         S         N        29563
# 33       S         S         N        24841
# 26       S         S         S        24939

# %%
# Criando um formatao para a visualização do formato dos padrões
pd.options.display.float_format = '{:,.2f}'.format
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 # Criando um formatao para a visualização do formato dos padrões
# ----> 2 pd.options.display.float_format = '{:,.2f}'.format
#
# NameError: name 'pd' is not defined

# %%
# Agrupando as informações por tipo de contúdo queremos analisar
base.groupby("Tipo")["Comentários"].count()
# Out:
# Tipo
# Foto     36
# IGTV      5
# Reels     5
# Vídeo     6
# Name: Comentários, dtype: int64

# %%
# Agrupando por Tipo e Pessoas
base.groupby(["Tipo","Pessoas"])["Curtidas"].mean()
# Out:
# Tipo   Pessoas
# Foto   N          3,863.50
#        S         15,236.67
# IGTV   S          6,833.40
# Reels  N          5,934.50
#        S         20,832.00
# Vídeo  N          4,007.50
#        S         16,409.50
# Name: Curtidas, dtype: float64

# %%
base.groupby(["Tipo","Pessoas"])[["Curtidas",'Comentários']].mean()
# Out:
#                Curtidas  Comentários
# Tipo  Pessoas
# Foto  N        3,863.50        29.50
#       S       15,236.67       226.20
# IGTV  S        6,833.40       133.60
# Reels N        5,934.50        98.00
#       S       20,832.00       342.00
# Vídeo N        4,007.50        65.25
#       S       16,409.50       370.00

# %%
base.groupby(["Tipo","Pessoas"])[["Curtidas",'Tags']].mean()
# Out:
#                Curtidas
# Tipo  Pessoas
# Foto  N        3,863.50
#       S       15,236.67
# IGTV  S        6,833.40
# Reels N        5,934.50
#       S       20,832.00
# Vídeo N        4,007.50
#       S       16,409.50

# %%
base.groupby("Pessoas")["Campanhas"].count()
# Out:
# Pessoas
# N    12
# S    40
# Name: Campanhas, dtype: int64

# %%
base.Tipo.value_counts().head(51).plot.bar();

# %%
base.Tags.value_counts().head(51).plot.bar();

# %% [markdown]
# # Conclusão:
# Analisando os dados e a bases fornecida para ánalise, encontramos alguns padrões que podem ser usados para gerar algumas respostas para o problema sugerido, pensamos em algumas dessas:
#
# incluir pessoas nas campanhas e nos post da empresa dão um aumento considerável para o engajamento da empresa.
#
# O vídeo não possuiu uma relevância muito grande, mas quando colocado em uma campanha e com pessoas ele aumenta sua interação,
# colocando ele perto dos níveis da foto.
#
# Para uma relevância maior dos níveis de engajamento da empresa, podemos observar que as publicações do tipo foto, com pessoas e de carater promoções/campanha possuem niveis maiores de engajamento, comparadoros com outros números de outros produtos, com níveis de interação maior, e maior relevância.
